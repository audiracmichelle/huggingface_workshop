# %% [markdown]
# <a href="https://colab.research.google.com/github/audiracmichelle/huggingface_workshop/blob/main/follow_along.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Hugging Face Workshop
# ---
#
# Use this notebook alongside the [workshop website](https://audiracmichelle.github.io/huggingface_workshop/) to run the code examples.
#
#
# ## Section 1 — Navigate the Hugging Face Ecosystem
#
# ### 1.2.3 Step 3 — Use the `datasets` library

# %% [markdown]
# #### Load a small dataset

# %%
"""
  Load a (small) dataset
"""

# %%
"""
  Print the DatasetDict
"""

# %% [markdown]
# #### Inspect splits, features, and shape

# %%
"""
  Print the dataset splits, features, and shape
"""

# %% [markdown]
# ### Pull samples and view images

# %%
"""
  Pull one sample from each split
"""

# %%
"""
  View image_test
"""

# %% [markdown]
# #### When to use `streaming=True`

# %%
"""
  Stream a (big/large) dataset
"""

# %%
"""
  Iterate and view a streamed sample
"""

# %%
"""
  View the annotation mask
"""

# %% [markdown]
# ### 1.3.3 Step 3 — Use the `transformers` library: Manual Inference with Model + Processor

# %% [markdown]
# #### Load model and processor

# %%
"""
  Load model and processor
"""

# %%
"""
  Process inputs
"""

# %% [markdown]
# #### Process inputs, run inference, post-process

# %%
"""
  Predict masks with torch.no_grad()
"""

# %%
"""
  Post-process: resize predictions back to original image size
"""

# %% [markdown]
# #### Visualize the results

# %%
"""
  Visualize: plot input image and predicted segmentation side by side
"""

# %%
"""
  Overlay the segmentation on the original image
"""

# %% [markdown]
# #### Inspect predicted classes

# %%
"""
  Inspect predicted classes
"""

# %% [markdown]
# ---
# ## Section 3 — Run Models in Minutes
# ### 3.1 Get Data Samples with `datasets`

# %%
"""
  Load the dataset and pull one sample from each split
"""

# %% [markdown]
# ### 3.2 Perform Inference with `transformers`

# %%
"""
  Create nvidia_segformer_pipeline and run on image_test
"""

# %%
"""
  Visualize selected class masks
"""

# %% [markdown]
# ### 3.3 Compare NVIDIA SegFormer and TCD-SegFormer on `image_test`

# %%
"""
  Create restor_tcd_pipeline and run both pipelines on image_test
"""

# %%
"""
  Side-by-side comparison on image_test
"""

# %% [markdown]
# ### 3.4 Discussion

# %%
"""
  Try it yourself: run SlimSAM-uniform-77 on your own image
"""
